# %%
class Solution(object):
    def longestCommonPrefix(self, strs):
        """
        :type strs: List[str]
        :rtype: str
        """
        if not strs :
            return ""
        strs.sort()
        first=strs[0]
        last=strs[-1]
        i=0
        if i<len(first) and i<len(last) and first[i]==last[i]:
            i+=1
        return first[:i]
class Solution(object):
    def longestCommonPrefix(self, strs):
        """
        :type strs: List[str]
        :rtype: str
        """
        if not strs:
            return ""
        
        # 将数组按字典顺序排序
        strs.sort()
        
        # 取排序后数组的第一个和最后一个字符串
        first = strs[0]
        last = strs[-1]
        
        # 找出第一个和最后一个字符串的共同前缀
        i = 0
        while i < len(first) and i < len(last) and first[i] == last[i]:
            i += 1
        
        return first[:i]

# 示例使用
solution = Solution()
strings = ["flower", "flow", "floight"]
print(solution.longestCommonPrefix(strings))  # 输出: "fl"

strings = ["dog", "doracecarog", "docar"]
print(solution.longestCommonPrefix(strings))  # 输出: ""
# Out:
# do

# %%
strs = ["banana", "apple", "cherry", "date"]

# 排序前的列表
print("排序前:", strs)

# 使用 sort() 方法对列表进行排序
strs.sort()

# 排序后的列表
print("排序后:", strs)
# Out:
# 排序前: ['banana', 'apple', 'cherry', 'date']
# 排序后: ['apple', 'banana', 'cherry', 'date']

# %%
first = ["flower", "flow", "floight"]
i = 2
a=first[0][0]
# 提取前缀
b=a[5]

print(a)  # 输出: "fl"
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[48], line 5
#       3 a=first[0][0]
#       4 # 提取前缀
# ----> 5 b=a[5]
#       7 print(a)  # 输出: "fl"
#
# IndexError: string index out of range
