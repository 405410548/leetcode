# %%
class Solution(object):
    def removeDuplicates(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        if not nums:
            return 0
        
        # 初始化下一个唯一元素的索引
        index = 1
        
        # 遍历数组
        for i in range(1, len(nums)):
            # 如果当前元素和前一个元素不同
            if nums[i] != nums[i - 1]:
                # 将当前元素赋值到下一个唯一的位置 
                nums[index] = nums[i]
                # 将索引前移
                index += 1
        
        # 返回唯一元素的个数
        return index


    # Test case 1: Regular input with duplicates
nums1 = [2, 2, 2, 3,5,5,6]
sol=Solution()

length = sol.removeDuplicates(nums1)

unique_nums = nums1[:4]

print(length)
print(unique_nums)
# Out:
# [2, 3, 5, 6, 5, 5, 6]
# 4
# [2, 3, 5, 6]

# %%
class Solution(object):
    def removeDuplicates(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        if not nums:
            return 0
        
        # 初始化下一个唯一元素的索引
        index = 1
        
        # 遍历数组
        for i in range(1, len(nums)):
            # 如果当前元素和前一个元素不同
            if nums[i] != nums[i - 1]:
                # 将当前元素赋值到下一个唯一的位置 
                nums[index] = nums[i]
                # 将索引前移
                index += 1
        
        # 返回唯一元素的个数
        return index


    # Test case 1: Regular input with duplicates
nums1 = [2, 2, 2, 3,5,5,6]
sol=Solution()

length = sol.removeDuplicates(nums1)

unique_nums = nums1[:4]

print(length)
print(unique_nums)

# %%
nums1 = [2, 2, 2, 3,5,5,6]
unique_nums = nums1[:4]
print(unique_nums)
# Out:
# [2, 2, 2, 3]

# %%
class Solution(object):
    def removeDuplicates(self, nums,val):
        """
        :type nums: List[int]
        :rtype: int
        """
        if not nums:
            return 0
        
        # 初始化下一个唯一元素的索引
        index = 1
        
        # 遍历数组
        for i in range(1, len(nums)):
            # 如果当前元素和前一个元素不同
            
            if nums[i] != nums[i - 1]:
                # 将当前元素赋值到下一个唯一的位置
                nums[index] = nums[i]
                # 将索引前移
                index += 1
        
        # 返回唯一元素的个数
        return index

# Test case: Regular input with duplicates
nums1 = [1, 1, 2, 3, 4,4,5]
sol = Solution()
length = sol.removeDuplicates(nums1)
sol.removeDuplicates(nums1)

# 输出结果，只保留独立的数字
unique_nums = nums1[:length]
print(unique_nums)
print(sol.removeDuplicates(nums1))
# Out:
# [1, 2, 3, 4, 5]
# 7
